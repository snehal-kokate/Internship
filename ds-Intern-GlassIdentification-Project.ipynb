# %% [markdown]
# # Glass Identification Project

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('glass.csv')
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
df.shape
# Out:
# (214, 10)

# %%
df.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %%
df.dtypes
# Out:
# RI      float64
# Na      float64
# Mg      float64
# Al      float64
# Si      float64
# K       float64
# Ca      float64
# Ba      float64
# Fe      float64
# Type      int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
df.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
df.Type.value_counts()
# Out:
# 2    76
# 1    70
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace = True)

# %%
df.nunique().to_frame('no of unique values')
# Out:
#       no of unique values
# RI                    178
# Na                    142
# Mg                     94
# Al                    118
# Si                    133
# K                      65
# Ca                    143
# Ba                     34
# Fe                     32
# Type                    6

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean     1.518348   13.404085    2.679202    1.449484   72.655070    0.498873
# std      0.003033    0.816662    1.443691    0.495925    0.773998    0.653185
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516520   12.900000    2.090000    1.190000   72.280000    0.130000
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.560000
# 75%      1.519150   13.810000    3.600000    1.630000   73.090000    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  213.000000  213.000000  213.000000  213.000000
# mean     8.954085    0.175869    0.057277    2.788732
# std      1.425882    0.498245    0.097589    2.105130
# ...

# %% [markdown]
# 1.If mean is greater than median(50%) then data is skewed to right.
# 2.but as we can see above mean is less than median or similar in some feature it means data skewed to left.
# 3.'K','ca','Ba' features indicate the presence of outliers in this columns.
# 4.because the 'max' value is larger than 75% percentile.

# %%
df.shape
# Out:
# (213, 10)

# %% [markdown]
# # Univariate Analysis

# %%
a = sns.countplot(x = 'Type',data=df)
print(df['Type'].value_counts())
# Out:
# 2    76
# 1    69
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type, dtype: int64

# %% [markdown]
# 1.we can see the class imbalance in target feature.
# 2.Unbalanced as the type5 and type 6 are very less compared to other type of glasses.
# 3.Mostly 1 and 2 types of glass is used.which is(1-   building_windows_float_processed
# 2- building_windows_non_float_processed).

# %%
df.columns.tolist()
# Out:
# ['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type']

# %%
sns.histplot(df['RI'])
# Out:
# <AxesSubplot:xlabel='RI', ylabel='Count'>

# %%
sns.histplot(df['Na'])
# Out:
# <AxesSubplot:xlabel='Na', ylabel='Count'>

# %%
sns.histplot(df['Mg'])
# Out:
# <AxesSubplot:xlabel='Mg', ylabel='Count'>

# %%
sns.histplot(df['Al'])
# Out:
# <AxesSubplot:xlabel='Al', ylabel='Count'>

# %%
sns.histplot(df['Si'])
# Out:
# <AxesSubplot:xlabel='Si', ylabel='Count'>

# %%
sns.histplot(df['K'])
# Out:
# <AxesSubplot:xlabel='K', ylabel='Count'>

# %%
sns.histplot(df['Ca'])
# Out:
# <AxesSubplot:xlabel='Ca', ylabel='Count'>

# %%
sns.histplot(df['Ba'])
# Out:
# <AxesSubplot:xlabel='Ba', ylabel='Count'>

# %%
sns.histplot(df['Fe'])
# Out:
# <AxesSubplot:xlabel='Fe', ylabel='Count'>

# %% [markdown]
# RI: positively skewed to right side.
# Na:It is showing positively skewed data distribution to right side.
# Mg:Negatively skewed data indicate distribution to left side.
# Al: Positively skewed data to right side.
# Si: Negatively skewed indicates on left side.
# K : Highly positively indicates a highly skewed distribution to right.
# Ca :Positive skewness indicate on right side,suggesting larger values.
# Ba :Highly positive skewness indicates a distribution on right side.
# Fe :positively skewness indicates on right side suggesting larger values.

# %% [markdown]
# # Distribution Plot

# %%
plt.figure(figsize=(10,6),facecolor = 'white')
plotnumber = 1
for col in df.columns:
    if plotnumber<=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df[col],color = 'm')
        plt.xlabel(col,fontsize=14)
        plt.yticks(rotation = 0,fontsize =12)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# 1.Non of feature is normally distributed.
# 2.The features Fe,Ba,Ca and K has highest skew coefficients.

# %%
df.skew()
# Out:
# RI      1.648017
# Na      0.465699
# Mg     -1.146096
# Al      0.938402
# Si     -0.744646
# K       6.545429
# Ca      2.050752
# Ba      3.406749
# Fe      1.747173
# Type    1.108861
# dtype: float64

# %% [markdown]
# # Bivariate Analysis

# %%
# Finding Outliers

# %%
sns.boxplot(x = df['Type'],y = df['RI'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='RI'>

# %%
sns.boxplot(x = df['Type'],y = df['Na'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Na'>

# %%
sns.boxplot(x = df['Type'],y = df['Mg'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Mg'>

# %%
sns.boxplot(x = df['Type'],y = df['Al'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Al'>

# %%
sns.boxplot(x = df['Type'],y = df['Si'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Si'>

# %%
sns.boxplot(x = df['Type'],y = df['K'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='K'>

# %%
sns.boxplot(x = df['Type'],y = df['Ca'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Ca'>

# %%
sns.boxplot(x = df['Type'],y = df['Ba'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Ba'>

# %%
sns.boxplot(x = df['Type'],y = df['Fe'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Fe'>

# %% [markdown]
# names = df.columns
# for i in range(len(names)-1):
#     fig = plt.figure()
#     ax = sns.boxplot(x='Type', y = names[i],data=df)

# %% [markdown]
# 1.The diamond shaped dots outside the boxplot indicates the outliers.
# 2.There are some extreme cases in K,Ba,and Fe.
# 3.we need to remove outliers to get better result.

# %% [markdown]
# # Multivariate Plot

# %%
plt.figure(figsize=(10,8))
sns.pairplot(df,hue = 'Type',palette = 'coolwarm')
plt.show()

# %% [markdown]
# 1.Pairplot to visually examine the correlation between features.

# %%
df.skew()
# Out:
# RI      1.648017
# Na      0.465699
# Mg     -1.146096
# Al      0.938402
# Si     -0.744646
# K       6.545429
# Ca      2.050752
# Ba      3.406749
# Fe      1.747173
# Type    1.108861
# dtype: float64

# %%
from scipy.stats import boxcox
feat = ['K','Ca','Ba','Fe']
for col in feat:
    df[col], _ = boxcox(df[col]+1)

# %% [markdown]
# 1.with this boxcox method we removed skewness of some features.

# %%
# Lets examine correlation between dependant and independant variable.
cor = df.corr()
cor
# Out:
#             RI        Na        Mg        Al        Si         K        Ca  \
# RI    1.000000 -0.198802 -0.127526 -0.400973 -0.539000 -0.303956  0.753460
# Na   -0.198802  1.000000 -0.278420  0.167735 -0.064885 -0.518127 -0.243674
# Mg   -0.127526 -0.278420  1.000000 -0.479575 -0.162437  0.383415 -0.360027
# Al   -0.400973  0.167735 -0.479575  1.000000 -0.016195  0.142647 -0.306158
# Si   -0.539000 -0.064885 -0.162437 -0.016195  1.000000 -0.085888 -0.133000
# K    -0.303956 -0.518127  0.383415  0.142647 -0.085888  1.000000 -0.462546
# Ca    0.753460 -0.243674 -0.360027 -0.306158 -0.133000 -0.462546  1.000000
# Ba   -0.123749  0.438986 -0.548663  0.579434  0.035782 -0.314374 -0.162580
# Fe    0.134354 -0.189662  0.104739 -0.093893 -0.080518  0.068162  0.124641
# Type -0.160140  0.508837 -0.744195  0.597432  0.147725 -0.336426 -0.043609
#
#             Ba        Fe      Type
# RI   -0.123749  0.134354 -0.160140
# Na    0.438986 -0.189662  0.508837
# Mg   -0.548663  0.104739 -0.744195
# ...

# %%
# Lets visualize the correlation between features
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),linewidth=0.1,fmt='.1g',linecolor = 'black',cmap = 'coolwarm',annot = True)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# 1.sodium(Na),aluminium(Al),Barium(Ba)seems to be strong positive correlation woth target variable Type.
#
# 2.This suggest that as the values of these features increase the 'type' of glass tends to have higher values.
# 3.Magnesium(mg),potassium(K) and Iron(Fe) have strong negatively correlation with target variable "Type'.
# 4.This suggest that as values of these features increase,the type of glass tends to have lower values.
# 5.RI,Si,Ca have weaker correlation with the target variable.

# %%
# checking correlation of every feature with target variable
cor['Type'].sort_values(ascending=False)
# Out:
# Type    1.000000
# Ba      0.668383
# Al      0.597432
# Na      0.508837
# Si      0.147725
# Ca     -0.043609
# RI     -0.160140
# Fe     -0.220262
# K      -0.336426
# Mg     -0.744195
# Name: Type, dtype: float64

# %% [markdown]
# # Seperating Features and Label

# %%
x = df.drop('Type',axis = 1)
y = df['Type']

# %% [markdown]
# # Feture Scaling using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
x = pd.DataFrame(scale.fit_transform(x),columns = x.columns)
x
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    0.879840  0.289558  1.257238 -0.706370 -1.133248 -1.294283 -0.007240
# 1   -0.243816  0.596403  0.639311 -0.180863  0.097037  0.269183 -0.880296
# 2   -0.716412  0.154546  0.604596  0.182950  0.433746  0.012845 -0.933987
# 3   -0.227291 -0.238216  0.701798 -0.322346 -0.058368  0.496450 -0.485018
# 4   -0.306608 -0.164573  0.653197 -0.423405  0.550299  0.448201 -0.632293
# ..        ...       ...       ...       ...       ...       ...       ...
# 208 -0.699888  0.903249 -1.860172  2.891336 -0.058368 -1.192605  0.337525
# 209 -0.494986  1.860605 -1.860172  1.092483  0.524398 -1.623427 -0.315601
# 210  0.760865  1.173272 -1.860172  1.153118  0.990612 -1.623427 -0.278988
# 211 -0.607351  1.197820 -1.860172  0.991424  1.236668 -1.623427 -0.242741
# 212 -0.409059  1.013713 -1.860172  1.274389  0.912909 -1.623427 -0.118678
#
#            Ba       Fe
# 0   -0.456097 -0.68218
# 1   -0.456097 -0.68218
# ...

# %% [markdown]
# 1.we use the standard scaler method to remove biasness of columns.
# 2.It is use to get same priority to every column.
# 3.we did not apply scaler method to taarget variable.

# %% [markdown]
# # Checking Variance Inflation Factor(VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['vif values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['features'] = x.columns
vif
# Out:
#    vif values features
# 0    7.201643       RI
# 1    4.052557       Na
# 2    4.538213       Mg
# 3    4.131512       Al
# 4    4.030473       Si
# 5    4.121421        K
# 6    6.255054       Ca
# 7    2.793071       Ba
# 8    1.092965       Fe

# %% [markdown]
# drop column which has higher vif value. which is 'RI' column.

# %%
x.drop('RI',axis = 1,inplace =True)

# %%
# again checking VIF to confirm multicoliniarity exist or not
vif = pd.DataFrame()
vif['vif values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['features'] = x.columns
vif
# Out:
#    vif values features
# 0    3.439995       Na
# 1    4.038515       Mg
# 2    2.610564       Al
# 3    1.595546       Si
# 4    3.995162        K
# 5    5.444259       Ca
# 6    2.610070       Ba
# 7    1.092131       Fe

# %%
y.value_counts()
# Out:
# 2    76
# 1    69
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type, dtype: int64

# %% [markdown]
# # Oversampling

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()
x1,y1 = sm.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 2    76
# 1    69
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type, dtype: int64

# %%
y1.value_counts() #Balanced Values
# Out:
# 1    76
# 2    76
# 3    76
# 5    76
# 6    76
# 7    76
# Name: Type, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,BaggingClassifier

from sklearn.metrics import classification_report,accuracy_score,confusion_matrix,roc_curve

from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Split data

# %%
x_train,x_test,y_train,y_test = train_test_split(x1,y1,test_size =0.20,random_state = 42)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (364, 8)
# (364,)
# (92, 8)
# (92,)

# %% [markdown]
# # Modeling

# %%
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
predrf = rf.predict(x_test)
print(accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# 0.8913043478260869
# [[13  1  3  0  0  0]
#  [ 3 16  0  0  0  0]
#  [ 2  0  8  0  0  0]
#  [ 0  0  0 14  0  0]
#  [ 0  0  0  0 14  0]
#  [ 0  1  0  0  0 17]]
#               precision    recall  f1-score   support
#
#            1       0.72      0.76      0.74        17
#            2       0.89      0.84      0.86        19
#            3       0.73      0.80      0.76        10
#            5       1.00      1.00      1.00        14
#            6       1.00      1.00      1.00        14
#            7       1.00      0.94      0.97        18
#
#     accuracy                           0.89        92
#    macro avg       0.89      0.89      0.89        92
# weighted avg       0.90      0.89      0.89        92

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
predlr = lr.predict(x_test)
print(accuracy_score(y_test,predlr))
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# 0.782608695652174
# [[13  1  3  0  0  0]
#  [ 3  9  6  1  0  0]
#  [ 5  0  5  0  0  0]
#  [ 0  0  0 14  0  0]
#  [ 0  0  0  0 14  0]
#  [ 0  0  1  0  0 17]]
#               precision    recall  f1-score   support
#
#            1       0.62      0.76      0.68        17
#            2       0.90      0.47      0.62        19
#            3       0.33      0.50      0.40        10
#            5       0.93      1.00      0.97        14
#            6       1.00      1.00      1.00        14
#            7       1.00      0.94      0.97        18
#
#     accuracy                           0.78        92
#    macro avg       0.80      0.78      0.77        92
# weighted avg       0.83      0.78      0.79        92

# %%
sv = SVC()
sv.fit(x_train,y_train)
predsv = sv.predict(x_test)
print(accuracy_score(y_test,predsv))
print(confusion_matrix(y_test,predsv))
print(classification_report(y_test,predsv))
# Out:
# 0.8260869565217391
# [[12  0  5  0  0  0]
#  [ 3 11  5  0  0  0]
#  [ 2  0  8  0  0  0]
#  [ 0  0  0 14  0  0]
#  [ 0  0  0  0 14  0]
#  [ 0  0  1  0  0 17]]
#               precision    recall  f1-score   support
#
#            1       0.71      0.71      0.71        17
#            2       1.00      0.58      0.73        19
#            3       0.42      0.80      0.55        10
#            5       1.00      1.00      1.00        14
#            6       1.00      1.00      1.00        14
#            7       1.00      0.94      0.97        18
#
#     accuracy                           0.83        92
#    macro avg       0.85      0.84      0.83        92
# weighted avg       0.88      0.83      0.84        92

# %%
gr = GradientBoostingClassifier()
gr.fit(x_train,y_train)
predgr = gr.predict(x_test)
print(accuracy_score(y_test,predgr))
print(confusion_matrix(y_test,predgr))
print(classification_report(y_test,predgr))
# Out:
# 0.9021739130434783
# [[14  2  1  0  0  0]
#  [ 4 15  0  0  0  0]
#  [ 1  0  9  0  0  0]
#  [ 0  0  0 14  0  0]
#  [ 0  0  0  0 14  0]
#  [ 1  0  0  0  0 17]]
#               precision    recall  f1-score   support
#
#            1       0.70      0.82      0.76        17
#            2       0.88      0.79      0.83        19
#            3       0.90      0.90      0.90        10
#            5       1.00      1.00      1.00        14
#            6       1.00      1.00      1.00        14
#            7       1.00      0.94      0.97        18
#
#     accuracy                           0.90        92
#    macro avg       0.91      0.91      0.91        92
# weighted avg       0.91      0.90      0.90        92

# %%
bg = BaggingClassifier()
bg.fit(x_train,y_train)
predbg = bg.predict(x_test)
print(accuracy_score(y_test,predbg))
print(confusion_matrix(y_test,predbg))
print(classification_report(y_test,predbg))
# Out:
# 0.8478260869565217
# [[13  1  3  0  0  0]
#  [ 3 14  2  0  0  0]
#  [ 2  2  6  0  0  0]
#  [ 0  0  0 14  0  0]
#  [ 0  0  0  0 14  0]
#  [ 1  0  0  0  0 17]]
#               precision    recall  f1-score   support
#
#            1       0.68      0.76      0.72        17
#            2       0.82      0.74      0.78        19
#            3       0.55      0.60      0.57        10
#            5       1.00      1.00      1.00        14
#            6       1.00      1.00      1.00        14
#            7       1.00      0.94      0.97        18
#
#     accuracy                           0.85        92
#    macro avg       0.84      0.84      0.84        92
# weighted avg       0.86      0.85      0.85        92

# %%
et = ExtraTreesClassifier()
et.fit(x_train,y_train)
predet = et.predict(x_test)
print(accuracy_score(y_test,predet))
print(confusion_matrix(y_test,predet))
print(classification_report(y_test,predet))
# Out:
# 0.9239130434782609
# [[13  2  2  0  0  0]
#  [ 2 17  0  0  0  0]
#  [ 0  0 10  0  0  0]
#  [ 0  0  0 14  0  0]
#  [ 0  0  0  0 14  0]
#  [ 1  0  0  0  0 17]]
#               precision    recall  f1-score   support
#
#            1       0.81      0.76      0.79        17
#            2       0.89      0.89      0.89        19
#            3       0.83      1.00      0.91        10
#            5       1.00      1.00      1.00        14
#            6       1.00      1.00      1.00        14
#            7       1.00      0.94      0.97        18
#
#     accuracy                           0.92        92
#    macro avg       0.92      0.93      0.93        92
# weighted avg       0.93      0.92      0.92        92

# %% [markdown]
# # Cross Validation Score

# %% [markdown]
# 1.cross validation allow us to choose the best performing model.
# 2.calculating difference between accuracy score and cross validation score
# 3.Checking cross validation score for each model.
# 4.performing cross validation on the same oversampled dataset which is used for training and testing models.

# %%
score = cross_val_score(rf,x1,y1)
print(score)
print(score.mean())
print('Difference between accuracy score and cv score is:',accuracy_score(y_test,predrf)-score.mean())
# Out:
# [0.84782609 0.79120879 0.8021978  0.78021978 0.89010989]
# 0.8223124701385572
# Difference between accuracy score and cv score is: 0.06899187768752968

# %%
score = cross_val_score(lr,x1,y1)
print(score)
print(score.mean())
print('Difference between accuracy score and cv score is:',accuracy_score(y_test,predlr)-score.mean())
# Out:
# [0.65217391 0.71428571 0.7032967  0.73626374 0.69230769]
# 0.6996655518394649
# Difference between accuracy score and cv score is: 0.08294314381270906

# %%
score = cross_val_score(sv,x1,y1)
print(score)
print(score.mean())
print('Difference between accuracy score and cv score is:',accuracy_score(y_test,predsv)-score.mean())
# Out:
# [0.77173913 0.74725275 0.75824176 0.82417582 0.76923077]
# 0.7741280458671763
# Difference between accuracy score and cv score is: 0.05195891065456282

# %%
score = cross_val_score(gr,x1,y1)
print(score)
print(score.mean())
print('Difference between accuracy score and cv score is:',accuracy_score(y_test,predgr)-score.mean())
# Out:
# [0.80434783 0.84615385 0.82417582 0.82417582 0.89010989]
# 0.837792642140468
# Difference between accuracy score and cv score is: 0.06438127090301027

# %%
score = cross_val_score(bg,x1,y1)
print(score)
print(score.mean())
print('Difference between accuracy score and cv score is:',accuracy_score(y_test,predbg)-score.mean())
# Out:
# [0.83695652 0.79120879 0.82417582 0.8021978  0.86813187]
# 0.8245341614906831
# Difference between accuracy score and cv score is: 0.02329192546583858

# %%
score = cross_val_score(et,x1,y1)
print(score)
print(score.mean())
print('Difference between accuracy score and cv score is:',accuracy_score(y_test,predet)-score.mean())
# Out:
# [0.88043478 0.78021978 0.78021978 0.78021978 0.91208791]
# 0.8266364070711896
# Difference between accuracy score and cv score is: 0.09727663640707129

# %% [markdown]
# Bagging Classifier is our best model as the difference between accuracy score and cross validation score is least.

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param = {'max_samples':[0.5,0.7,0.9],
         'random_state':[10,50,200],
         'max_features':[0.5,0.7,0.9],
        'n_estimators':[50,100,200]}

# %%
gcv = GridSearchCV(BaggingClassifier(),param,cv=5)
# make combination of parameters where algorithm has highest accuracy
# If cv = 5 it means y1 data divided into 5 equal parts

# %%
gcv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=BaggingClassifier(),
#              param_grid={'max_features': [0.5, 0.7, 0.9],
#                          'max_samples': [0.5, 0.7, 0.9],
#                          'n_estimators': [50, 100, 200],
#                          'random_state': [10, 50, 200]})

# %%
gcv.best_params_
# Out:
# {'max_features': 0.7,
#  'max_samples': 0.5,
#  'n_estimators': 50,
#  'random_state': 10}

# %%
final_model = BaggingClassifier(max_features =0.7,max_samples = 0.5,n_estimators = 50,random_state=10)
final_model.fit(x_train,y_train)
pred = final_model.predict(x_test)
acc = accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 90.21739130434783

# %% [markdown]
# # Saving Model

# %%
import joblib
joblib.dump(final_model,'Glass_types.pkl')
# Out:
# ['Glass_types.pkl']

# %%
model = joblib.load('Glass_types.pkl')
# prediction
preds = model.predict(x_test)
preds
# Out:
# array([6, 1, 5, 1, 3, 7, 5, 1, 6, 1, 2, 5, 1, 6, 6, 1, 5, 5, 7, 2, 2, 2,
#        3, 2, 3, 7, 2, 7, 1, 3, 6, 3, 1, 2, 7, 2, 5, 5, 2, 2, 6, 2, 7, 2,
#        3, 2, 1, 3, 7, 5, 1, 1, 3, 5, 6, 7, 1, 6, 1, 7, 5, 3, 3, 7, 5, 1,
#        7, 6, 5, 7, 5, 6, 1, 6, 7, 7, 1, 6, 7, 2, 6, 5, 6, 1, 1, 7, 7, 2,
#        2, 1, 1, 3], dtype=int64)

# %%
a = np.array(y_test)
df1 = pd.DataFrame()
df1['predicted'] = preds
df1['original'] = a

# %%
df1
# Out:
#     predicted  original
# 0           6         6
# 1           1         1
# 2           5         5
# 3           1         1
# 4           3         3
# ..        ...       ...
# 87          2         2
# 88          2         2
# 89          1         1
# 90          1         3
# 91          3         1
#
# [92 rows x 2 columns]

# %%
----------------------------------------------------------------------
